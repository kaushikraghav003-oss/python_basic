# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushikraghav003-oss/python_basic/blob/main/Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find the CI and take the value from the user.

Principal=int(input("ENETER THE Principal Amount: "))
Time=int(input("ENETER THE Time: "))
Rate=int(input("ENETER THE Rate: "))
result=Principal*((1+(Rate/100))**Time)
print("Compound Interest : ",result)
# Out:
# ENETER THE Principal Amount: 4000
# ENETER THE Time: 3
# ENETER THE Rate: 12
# Compound Interest :  5619.712000000001

# %%
# set datatype
# a={10,20,30,30,30}
a={10,20,30,30,30}
print(a)
print(type(a))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
# Q1. wap to add two number input should be taken from user datatype <int,float>
a=int(input("ENETER THE FIRST NUMBER: "))
b=float(input("ENETER THE FIRST NUMBER: "))

print("TYPE OF 1st NUMBER: ",type(a))
print("TYPE OF 2ND NUMBER: ",type(b))
# Out:
# ENETER THE FIRST NUMBER: 12
# ENETER THE FIRST NUMBER: 12
# TYPE OF 1st NUMBER:  <class 'int'>
# TYPE OF 2ND NUMBER:  <class 'float'>

# %%
# CHECK THAT A GIVEN NUMBER IF EVEN OR ODD
a=int(input("ENETER THE NUMBER: "))
if a%2==0:
    print("Even number : ",a)

else:
    print("Odd number : ",a)
# Out:
# ENETER THE NUMBER: 20
# Even number :  20

# %%
# LARGEST AMONG 2 NUMBER
a=int(input("ENETER THE FIRST NUMBER: "))
b=int(input("ENETER THE Second NUMBER: "))
if a>b:
    print("Largest number is 1st: ",a)

else:
    print("Largest number is 2nd: ",b)
# Out:
# ENETER THE FIRST NUMBER: 23
# ENETER THE Second NUMBER: 56
# Largest number is 2nd:  56

# %%
# check the given number is prime or not
a=int(input("ENETER THE FIRST NUMBER: "))
if a<=1:
    print("Non prime : ",a)

else:
    for i in range (2,a+1):
        if(a%i==0):
            print("Non prime : ",a)
            break

    else:
        print("Prime : ",a)
# Out:
# ENETER THE FIRST NUMBER: 45
# Non prime :  45
