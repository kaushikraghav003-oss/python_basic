# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushikraghav003-oss/python_basic/blob/main/Experiment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to check whether a number is even or odd

# %%
a=int(input("Enter the number:"))
for i in range(1):
  if a%2==0:
    print(a,"Even number")
  else:
    print(a,"Odd number")
# Out:
# Enter the number:23
# 23 Odd number

# %%
# program to print the decimal equivalents

# %%
for i in range(2,11):
  print("1/",i,"=",1/i)
# Out:
# 1/ 2 = 0.5
# 1/ 3 = 0.3333333333333333
# 1/ 4 = 0.25
# 1/ 5 = 0.2
# 1/ 6 = 0.16666666666666666
# 1/ 7 = 0.14285714285714285
# 1/ 8 = 0.125
# 1/ 9 = 0.1111111111111111
# 1/ 10 = 0.1
