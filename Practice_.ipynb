# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushikraghav003-oss/python_basic/blob/main/Practice_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check Whether a Number is Positive, Negative, or Zero

# %%
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number: 34
# Positive

# %%
#Check whether a number is divisible by 5 and 11

# %%
num = int(input("Enter a number: "))
if num % 5 == 0 and num % 11 == 0:
    print("Divisible by both 5 and 11")
else:
    print("Not divisible by both 5 and 11")
# Out:
# Enter a number: 34
# Not divisible by both 5 and 11

# %%
#Printing Squares of Numbers Using a For Loop

# %%
for i in range(1, 11):
    print(f"{i}^2 = {i*i}")
# Out:
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25
# 6^2 = 36
# 7^2 = 49
# 8^2 = 64
# 9^2 = 81
# 10^2 = 100
